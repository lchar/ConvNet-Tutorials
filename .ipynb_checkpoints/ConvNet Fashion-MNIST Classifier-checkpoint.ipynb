# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
# add a dimension for convnet compatibility
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# Data Preprocessing

# %%
plt.figure()
plt.imshow(train_images[0, :, :, 0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i,:,:,0], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# Model construction

# %%
l2_coeff = 0.0001

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=regularizers.l2(l2_coeff), 
                       input_shape=(28, 28, 1)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu',
                       kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.3))

#model.add(layers.Conv2D(128, (3, 3), activation='relu',
#                       kernel_regularizer=regularizers.l2(l2_coeff)))
#model.add(layers.BatchNormalization())
#model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu',
#                       kernel_regularizer=regularizers.l2(l2_coeff)))
#model.add(layers.BatchNormalization())
#model.add(layers.MaxPooling2D((2,2)))
#model.add(layers.Dropout(0.4))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# =================================================================
# Total params: 65,760
# Trainable params: 65,376
# Non-trainable params: 384
# _________________________________________________________________

# %%
model.add(layers.Flatten())
#model.add(layers.Dense(1024, activation='relu',
#                      kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(128, activation='relu',
                      kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(32, activation='relu',
                      kernel_regularizer=regularizers.l2(l2_coeff)))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='softmax',
                      kernel_regularizer=regularizers.l2(l2_coeff)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               295040
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 365,258
# Trainable params: 364,874
# Non-trainable params: 384
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=50,
                   validation_data=(test_images, test_labels))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 57s 954us/sample - loss: 0.7352 - accuracy: 0.7551 - val_loss: 0.4245 - val_accuracy: 0.8731
# Epoch 2/50
# 60000/60000 [==============================] - 49s 825us/sample - loss: 0.4882 - accuracy: 0.8550 - val_loss: 0.3984 - val_accuracy: 0.8862
# Epoch 3/50
# 60000/60000 [==============================] - 51s 854us/sample - loss: 0.4375 - accuracy: 0.8806 - val_loss: 0.3901 - val_accuracy: 0.8935
# Epoch 4/50
# 60000/60000 [==============================] - 50s 838us/sample - loss: 0.4264 - accuracy: 0.8909 - val_loss: 0.3846 - val_accuracy: 0.9004
# Epoch 5/50
# 60000/60000 [==============================] - 50s 840us/sample - loss: 0.4179 - accuracy: 0.8971 - val_loss: 0.3622 - val_accuracy: 0.9156
# Epoch 6/50
# 60000/60000 [==============================] - 50s 840us/sample - loss: 0.4123 - accuracy: 0.9032 - val_loss: 0.4032 - val_accuracy: 0.8994
# Epoch 7/50
# 60000/60000 [==============================] - 50s 839us/sample - loss: 0.4091 - accuracy: 0.9039 - val_loss: 0.3702 - val_accuracy: 0.9154
# Epoch 8/50
# 60000/60000 [==============================] - 50s 838us/sample - loss: 0.3976 - accuracy: 0.9089 - val_loss: 0.3821 - val_accuracy: 0.9081
# Epoch 9/50
# 60000/60000 [==============================] - 50s 841us/sample - loss: 0.3971 - accuracy: 0.9111 - val_loss: 0.3946 - val_accuracy: 0.9019
# Epoch 10/50
# 60000/60000 [==============================] - 51s 851us/sample - loss: 0.3902 - accuracy: 0.9135 - val_loss: 0.3954 - val_accuracy: 0.9063
# Epoch 11/50
# 60000/60000 [==============================] - 50s 840us/sample - loss: 0.3901 - accuracy: 0.9132 - val_loss: 0.3576 - val_accuracy: 0.9190
# Epoch 12/50
# 60000/60000 [==============================] - 51s 846us/sample - loss: 0.3856 - accuracy: 0.9152 - val_loss: 0.3575 - val_accuracy: 0.9226
# Epoch 13/50
# 60000/60000 [==============================] - 52s 868us/sample - loss: 0.3821 - accuracy: 0.9186 - val_loss: 0.3552 - val_accuracy: 0.9236
# Epoch 14/50
# 60000/60000 [==============================] - 52s 868us/sample - loss: 0.3771 - accuracy: 0.9199 - val_loss: 0.3513 - val_accuracy: 0.9249
# Epoch 15/50
# 60000/60000 [==============================] - 49s 825us/sample - loss: 0.3773 - accuracy: 0.9209 - val_loss: 0.3591 - val_accuracy: 0.9278
# Epoch 16/50
# 60000/60000 [==============================] - 50s 838us/sample - loss: 0.3770 - accuracy: 0.9207 - val_loss: 0.3534 - val_accuracy: 0.9237
# Epoch 17/50
# 60000/60000 [==============================] - 50s 839us/sample - loss: 0.3744 - accuracy: 0.9211 - val_loss: 0.3613 - val_accuracy: 0.9214
# Epoch 18/50
# 60000/60000 [==============================] - 51s 851us/sample - loss: 0.3695 - accuracy: 0.9239 - val_loss: 0.3643 - val_accuracy: 0.9244
# Epoch 19/50
# 60000/60000 [==============================] - 51s 842us/sample - loss: 0.3690 - accuracy: 0.9250 - val_loss: 0.3635 - val_accuracy: 0.9240
# Epoch 20/50
# 60000/60000 [==============================] - 50s 841us/sample - loss: 0.3697 - accuracy: 0.9246 - val_loss: 0.4175 - val_accuracy: 0.9038
# Epoch 21/50
# 60000/60000 [==============================] - 50s 840us/sample - loss: 0.3629 - accuracy: 0.9265 - val_loss: 0.3536 - val_accuracy: 0.9269
# Epoch 22/50
# 60000/60000 [==============================] - 50s 840us/sample - loss: 0.3622 - accuracy: 0.9259 - val_loss: 0.3487 - val_accuracy: 0.9314
# Epoch 23/50
# 60000/60000 [==============================] - 50s 841us/sample - loss: 0.3663 - accuracy: 0.9251 - val_loss: 0.3542 - val_accuracy: 0.9265
# Epoch 24/50
# 60000/60000 [==============================] - 50s 831us/sample - loss: 0.3618 - accuracy: 0.9268 - val_loss: 0.3431 - val_accuracy: 0.9306
# Epoch 25/50
# 60000/60000 [==============================] - 50s 834us/sample - loss: 0.3610 - accuracy: 0.9268 - val_loss: 0.3443 - val_accuracy: 0.9292
# Epoch 26/50
# 60000/60000 [==============================] - 50s 829us/sample - loss: 0.3583 - accuracy: 0.9281 - val_loss: 0.3500 - val_accuracy: 0.9284
# Epoch 27/50
# 60000/60000 [==============================] - 50s 826us/sample - loss: 0.3605 - accuracy: 0.9277 - val_loss: 0.3498 - val_accuracy: 0.9325
# Epoch 28/50
# 60000/60000 [==============================] - 50s 827us/sample - loss: 0.3564 - accuracy: 0.9284 - val_loss: 0.3567 - val_accuracy: 0.9277
# Epoch 29/50
# 60000/60000 [==============================] - 50s 825us/sample - loss: 0.3558 - accuracy: 0.9291 - val_loss: 0.3385 - val_accuracy: 0.9324
# Epoch 30/50
# 60000/60000 [==============================] - 50s 832us/sample - loss: 0.3563 - accuracy: 0.9282 - val_loss: 0.3492 - val_accuracy: 0.9285
# Epoch 31/50
# 60000/60000 [==============================] - 50s 839us/sample - loss: 0.3573 - accuracy: 0.9286 - val_loss: 0.3490 - val_accuracy: 0.9279
# Epoch 32/50
# 60000/60000 [==============================] - 49s 818us/sample - loss: 0.3552 - accuracy: 0.9301 - val_loss: 0.3491 - val_accuracy: 0.9286
# Epoch 33/50
# 60000/60000 [==============================] - 50s 826us/sample - loss: 0.3521 - accuracy: 0.9300 - val_loss: 0.3650 - val_accuracy: 0.9268
# Epoch 34/50
# 60000/60000 [==============================] - 49s 814us/sample - loss: 0.3540 - accuracy: 0.9298 - val_loss: 0.3534 - val_accuracy: 0.9266
# Epoch 35/50
# 60000/60000 [==============================] - 49s 818us/sample - loss: 0.3515 - accuracy: 0.9298 - val_loss: 0.3476 - val_accuracy: 0.9279
# Epoch 36/50
# 60000/60000 [==============================] - 49s 821us/sample - loss: 0.3495 - accuracy: 0.9322 - val_loss: 0.3497 - val_accuracy: 0.9292
# Epoch 37/50
# 60000/60000 [==============================] - 50s 826us/sample - loss: 0.3528 - accuracy: 0.9299 - val_loss: 0.3590 - val_accuracy: 0.9259
# Epoch 38/50
# 60000/60000 [==============================] - 51s 843us/sample - loss: 0.3487 - accuracy: 0.9311 - val_loss: 0.3490 - val_accuracy: 0.9301
# Epoch 39/50
# 60000/60000 [==============================] - 50s 829us/sample - loss: 0.3527 - accuracy: 0.9304 - val_loss: 0.3421 - val_accuracy: 0.9322
# Epoch 40/50
# 60000/60000 [==============================] - 50s 828us/sample - loss: 0.3461 - accuracy: 0.9324 - val_loss: 0.3579 - val_accuracy: 0.9291
# Epoch 41/50
# 60000/60000 [==============================] - 50s 825us/sample - loss: 0.3494 - accuracy: 0.9303 - val_loss: 0.3503 - val_accuracy: 0.9280
# Epoch 42/50
# 60000/60000 [==============================] - 50s 830us/sample - loss: 0.3464 - accuracy: 0.9323 - val_loss: 0.3430 - val_accuracy: 0.9303
# Epoch 43/50
# 60000/60000 [==============================] - 50s 835us/sample - loss: 0.3478 - accuracy: 0.9326 - val_loss: 0.3409 - val_accuracy: 0.9324
# Epoch 44/50
# 60000/60000 [==============================] - 50s 825us/sample - loss: 0.3489 - accuracy: 0.9340 - val_loss: 0.3563 - val_accuracy: 0.9253
# Epoch 45/50
# 60000/60000 [==============================] - 49s 811us/sample - loss: 0.3432 - accuracy: 0.9335 - val_loss: 0.3416 - val_accuracy: 0.9294
# Epoch 46/50
# 60000/60000 [==============================] - 48s 808us/sample - loss: 0.3465 - accuracy: 0.9334 - val_loss: 0.3497 - val_accuracy: 0.9276
# Epoch 47/50
# 60000/60000 [==============================] - 49s 809us/sample - loss: 0.3461 - accuracy: 0.9330 - val_loss: 0.3389 - val_accuracy: 0.9312
# Epoch 48/50
# 60000/60000 [==============================] - 48s 808us/sample - loss: 0.3453 - accuracy: 0.9322 - val_loss: 0.3412 - val_accuracy: 0.9317
# Epoch 49/50
# 60000/60000 [==============================] - 48s 808us/sample - loss: 0.3481 - accuracy: 0.9325 - val_loss: 0.3363 - val_accuracy: 0.9315
# Epoch 50/50
# 60000/60000 [==============================] - 49s 817us/sample - loss: 0.3413 - accuracy: 0.9327 - val_loss: 0.3535 - val_accuracy: 0.9281

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/1 - 3s - loss: 0.3875 - accuracy: 0.9281
#
# Test accuracy: 0.9281

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 10000/1 - 3s - loss: 0.3875 - accuracy: 0.9281

# %% [markdown]
# Make predictions

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([2.5144684e-13, 4.6585028e-16, 8.9755704e-14, 2.8173788e-15,
#        1.2152399e-14, 4.0055394e-08, 1.2947194e-14, 1.5385943e-06,
#        5.5689703e-13, 9.9999845e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    """
    Shows the image with prediction and predicted label with calculated
    probability.
    """
    predictions_array, true_label, img = predictions_array, true_label[i], \
                                         img[i,:,:,0]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    """
    Shows a bar graph of the calculated probabilities.
    """
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
start_image = 150 # Set to 0 for first images
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(start_image + i, predictions[start_image + i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(start_image + i, predictions[start_image + i], test_labels)
plt.tight_layout()
plt.show()
