# %% [markdown]
# # Fashion-MNIST Classifier Using Convolution Neural Networks
#
# In this notebook we attempt to classify images from the Fashion-MNIST data set using convolutional neural networks. We perform close to state of the art performance with validation accuracy in the 93%-94% range.
#
# The structure of the model has been inspired by a [TensorFlow Tutorial](https://www.tensorflow.org/tutorials/keras/classification) and a [model](https://github.com/mjbhobe/dl-tensorflow-keras/blob/master/Fashion%20-%20CNN%20-%20Keras.ipynb) by Manish Bhobe.

# %% [markdown]
# ### Table of Contents
#
# - [0. Loading Packages and Data](#0.-Loading-Packages-and-Data)
# - [1. Data Preprocessing](#1.-Data-Preprocessing)
# - [2. Model Construction](#2.-Model-Construction)
# - [3. Model Training](#3.-Model-Training)
# - [4. Prediction Visualizations](#4.-Prediction-Visualizations)

# %% [markdown]
# ## 0. Loading Packages and Data

# %% [markdown]
# The convolutional network was built using the Keras API, now officially implemented in TensorFlow.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers, callbacks, optimizers

# %% [markdown]
# We will also need Numpy for some data processing and Matplotlib for graphs.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Since my GPU has a compute capability of 3.0, I have to use version 2.0 of TensorFlow, but the script should work for 2.1 as well.
#
# ##### To do:
# Test this in CPU mode version 2.1.

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
seed = 0
tf.random.set_seed(seed)

# %%
fashion_mnist = datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
# add a dimension for convnet compatibility
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# ## 1. Data Preprocessing

# %%
plt.figure()
plt.imshow(train_images[0, :, :, 0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i,:,:,0], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## 2. Model construction

# %%
l2_coeff = 0.01 # Change to coefficient (Not using it?)
reg_l2 = regularizers.l2(l2_coeff)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=None, 
                       input_shape=(28, 28, 1)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=None))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3, 3), padding='valid', activation='relu',
                       kernel_regularizer=None))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=None))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=None))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu',
                       kernel_regularizer=None))
model.add(layers.BatchNormalization())
model.add(layers.GlobalAveragePooling2D())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# =================================================================
# Total params: 288,224
# Trainable params: 287,328
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu',
                      kernel_regularizer=reg_l2))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(256, activation='relu',
                      kernel_regularizer=reg_l2))
#model.add(layers.Dropout(0.2))
#model.add(layers.Dense(128, activation='relu'
#                      kernel_regularizer=reg_l2))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(10, activation='softmax', 
                      kernel_regularizer=reg_l2))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              132096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 685,290
# Trainable params: 684,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

# The following is a function that returns the learning rate, to be used as a metric during training
#def get_lr_metric(optimizer):
#    def lr(y_true, y_pred):
#        return optimizer.lr
#    return lr
#
#lr_metric = get_lr_metric(opt)

# %%
cbacks = [
                # reduce learning rate by a factor of 5 (i.e. lr/=5.0) 
                # if val_loss does not reduce for 3 epochs
                callbacks.ReduceLROnPlateau(
                    monitor='val_loss',
                    factor=0.2,
                    patience=3
                ),
                # Stop training if val_acc does not improve for
                # 5 or more epochs
                callbacks.EarlyStopping(
                    monitor='val_accuracy',
                    patience=10,
                    restore_best_weights=True
                )
            ]

# %% [markdown]
# ## 3. Model Training

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'], callbacks=cbacks)

history = model.fit(train_images, train_labels, epochs=200, batch_size=128,
                   validation_data=(test_images, test_labels), callbacks = cbacks)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 50s 834us/sample - loss: 1.1314 - accuracy: 0.8432 - val_loss: 1.5460 - val_accuracy: 0.5987
# Epoch 2/200
# 60000/60000 [==============================] - 44s 727us/sample - loss: 0.4967 - accuracy: 0.9009 - val_loss: 0.4896 - val_accuracy: 0.9013
# Epoch 3/200
# 60000/60000 [==============================] - 43s 724us/sample - loss: 0.4348 - accuracy: 0.9160 - val_loss: 0.5333 - val_accuracy: 0.8669
# Epoch 4/200
# 60000/60000 [==============================] - 44s 740us/sample - loss: 0.3921 - accuracy: 0.9270 - val_loss: 0.4555 - val_accuracy: 0.8979
# Epoch 5/200
# 60000/60000 [==============================] - 44s 726us/sample - loss: 0.3677 - accuracy: 0.9318 - val_loss: 0.3976 - val_accuracy: 0.9191
# Epoch 6/200
# 60000/60000 [==============================] - 44s 735us/sample - loss: 0.3409 - accuracy: 0.9397 - val_loss: 0.3948 - val_accuracy: 0.9191
# Epoch 7/200
# 60000/60000 [==============================] - 44s 731us/sample - loss: 0.3188 - accuracy: 0.9448 - val_loss: 0.4050 - val_accuracy: 0.9195
# Epoch 8/200
# 60000/60000 [==============================] - 44s 725us/sample - loss: 0.3087 - accuracy: 0.9475 - val_loss: 0.3632 - val_accuracy: 0.9233
# Epoch 9/200
# 60000/60000 [==============================] - 44s 732us/sample - loss: 0.2833 - accuracy: 0.9543 - val_loss: 0.3724 - val_accuracy: 0.9232
# Epoch 10/200
# 60000/60000 [==============================] - 44s 726us/sample - loss: 0.2674 - accuracy: 0.9578 - val_loss: 0.3690 - val_accuracy: 0.9210
# Epoch 11/200
# 60000/60000 [==============================] - 44s 727us/sample - loss: 0.2492 - accuracy: 0.9626 - val_loss: 0.3571 - val_accuracy: 0.9244
# Epoch 12/200
# 60000/60000 [==============================] - 45s 748us/sample - loss: 0.2342 - accuracy: 0.9667 - val_loss: 0.3764 - val_accuracy: 0.9197
# Epoch 13/200
# 60000/60000 [==============================] - 50s 835us/sample - loss: 0.2193 - accuracy: 0.9710 - val_loss: 0.3668 - val_accuracy: 0.9192
# Epoch 14/200
# 60000/60000 [==============================] - 48s 796us/sample - loss: 0.2111 - accuracy: 0.9732 - val_loss: 0.4409 - val_accuracy: 0.8994
# Epoch 15/200
# 60000/60000 [==============================] - 45s 752us/sample - loss: 0.1597 - accuracy: 0.9893 - val_loss: 0.3145 - val_accuracy: 0.9365
# Epoch 16/200
# 60000/60000 [==============================] - 45s 743us/sample - loss: 0.1444 - accuracy: 0.9942 - val_loss: 0.3214 - val_accuracy: 0.9378
# Epoch 17/200
# 60000/60000 [==============================] - 43s 724us/sample - loss: 0.1387 - accuracy: 0.9960 - val_loss: 0.3297 - val_accuracy: 0.9348
# Epoch 18/200
# 60000/60000 [==============================] - 44s 733us/sample - loss: 0.1347 - accuracy: 0.9966 - val_loss: 0.3233 - val_accuracy: 0.9345
# Epoch 19/200
# 60000/60000 [==============================] - 45s 742us/sample - loss: 0.1283 - accuracy: 0.9982 - val_loss: 0.3187 - val_accuracy: 0.9380
# Epoch 20/200
# 60000/60000 [==============================] - 44s 733us/sample - loss: 0.1269 - accuracy: 0.9985 - val_loss: 0.3190 - val_accuracy: 0.9367
# Epoch 21/200
# 60000/60000 [==============================] - 44s 735us/sample - loss: 0.1260 - accuracy: 0.9987 - val_loss: 0.3196 - val_accuracy: 0.9381
# Epoch 22/200
# 60000/60000 [==============================] - 44s 729us/sample - loss: 0.1249 - accuracy: 0.9989 - val_loss: 0.3178 - val_accuracy: 0.9384
# Epoch 23/200
# 60000/60000 [==============================] - 44s 727us/sample - loss: 0.1247 - accuracy: 0.9988 - val_loss: 0.3177 - val_accuracy: 0.9387
# Epoch 24/200
# 60000/60000 [==============================] - 44s 726us/sample - loss: 0.1241 - accuracy: 0.9989 - val_loss: 0.3172 - val_accuracy: 0.9382
# Epoch 25/200
# 60000/60000 [==============================] - 44s 739us/sample - loss: 0.1237 - accuracy: 0.9991 - val_loss: 0.3173 - val_accuracy: 0.9383
# Epoch 26/200
# 60000/60000 [==============================] - 44s 734us/sample - loss: 0.1234 - accuracy: 0.9991 - val_loss: 0.3178 - val_accuracy: 0.9384
# Epoch 27/200
# 60000/60000 [==============================] - 44s 733us/sample - loss: 0.1239 - accuracy: 0.9991 - val_loss: 0.3179 - val_accuracy: 0.9381
# Epoch 28/200
# 60000/60000 [==============================] - 44s 732us/sample - loss: 0.1236 - accuracy: 0.9991 - val_loss: 0.3178 - val_accuracy: 0.9381
# Epoch 29/200
# 60000/60000 [==============================] - 44s 727us/sample - loss: 0.1238 - accuracy: 0.9990 - val_loss: 0.3177 - val_accuracy: 0.9381
# Epoch 30/200
# 60000/60000 [==============================] - 44s 735us/sample - loss: 0.1239 - accuracy: 0.9990 - val_loss: 0.3175 - val_accuracy: 0.9383
# Epoch 31/200
# 60000/60000 [==============================] - 44s 733us/sample - loss: 0.1238 - accuracy: 0.9991 - val_loss: 0.3179 - val_accuracy: 0.9378
# Epoch 32/200
# 60000/60000 [==============================] - 44s 734us/sample - loss: 0.1238 - accuracy: 0.9991 - val_loss: 0.3174 - val_accuracy: 0.9376
# Epoch 33/200
# 60000/60000 [==============================] - 44s 727us/sample - loss: 0.1235 - accuracy: 0.9991 - val_loss: 0.3176 - val_accuracy: 0.9383

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/1 - 4s - loss: 0.3149 - accuracy: 0.9387
#
# Test accuracy: 0.9387

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 10000/1 - 4s - loss: 0.3149 - accuracy: 0.9387

# %% [markdown]
# ## 4. Prediction Visualizations

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([2.5038704e-05, 1.7452816e-05, 5.9043069e-04, 1.7705313e-03,
#        3.7724876e-05, 5.5062567e-04, 6.6862660e-05, 2.9770419e-04,
#        5.4674409e-04, 9.9609691e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    """
    Shows the image with prediction and predicted label with calculated
    probability.
    """
    predictions_array, true_label, img = predictions_array, true_label[i], \
                                         img[i,:,:,0]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    """
    Shows a bar graph of the calculated probabilities.
    """
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
start_image = 100 # Set to 0 for first images
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(start_image + i, predictions[start_image + i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(start_image + i, predictions[start_image + i], test_labels)
plt.tight_layout()
plt.show()
